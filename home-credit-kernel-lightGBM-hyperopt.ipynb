# %%
import os
import csv
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from hyperopt import hp, tpe, STATUS_OK
from hyperopt.fmin import fmin
from hyperopt import Trials

# %%
DATA_DIR = '/home/yukimiki/.kaggle/competitions/home-credit-default-risk/'

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# %%
# One-hot encoding for categorical columns with get_dummies
def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# %%
# Preprocess application_train.csv and application_test.csv
def application_train_test(num_rows = None, nan_as_category = False):
    # Read data and merge
    df = pd.read_csv(os.path.join(DATA_DIR, 'application_train.csv'), nrows= num_rows)
    test_df = pd.read_csv(os.path.join(DATA_DIR, 'application_test.csv'), nrows= num_rows)
    print("Train samples: {}, test samples: {}".format(len(df), len(test_df)))
    df = df.append(test_df).reset_index()
    # Optional: Remove 4 applications with XNA CODE_GENDER (train set)
    df = df[df['CODE_GENDER'] != 'XNA']
    # drop certiain clomns
    """
    drop_colmns = ['AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_MON'
                               , 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_WEEK', 'LIVINGAPARTMENTS_MODE'
                               , 'BASEMENTAREA_MODE', 'BASEMENTAREA_MEDI'
                               , 'COMMONAREA_AVG', 'DEF_30_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'ELEVATORS_MODE'
                               , 'ELEVATORS_AVG', 'ENTRANCES_MODE', 'ENTRANCES_AVG', 'FLOORSMAX_MODE', 'FLOORSMAX_AVG'
                               , 'FLOORSMIN_MODE', 'FLOORSMIN_AVG', 'LANDAREA_MODE', 'LANDAREA_AVG'
                               , 'LIVINGAPARTMENTS_MEDI', 'LIVINGAPARTMENTS_MODE', 'LIVINGAREA_AVG', 'LIVINGAREA_MEDI', 'LIVINGAREA_MODE'
                               , 'NONLIVINGAPARTMENTS_MEDI', 'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MEDI', 'NONLIVINGAREA_MODE'
                               , 'OBS_60_CNT_SOCIAL_CIRCLE', 'REGION_RATING_CLIENT_W_CITY', 'YEARS_BEGINEXPLUATATION_MEDI'
                               , 'YEARS_BEGINEXPLUATATION_MODE', 'YEARS_BUILD_MEDI', 'YEARS_BUILD_MODE']
    df = df.drop(drop_colmns, axis=1)
    """
    # Categorical features with Binary encode (0 or 1; two categories)
    for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
        df[bin_feature], uniques = pd.factorize(df[bin_feature])
    # Categorical features with One-Hot encode
    df, cat_cols = one_hot_encoder(df, nan_as_category)
    
    # NaN values for DAYS_EMPLOYED: 365.243 -> nan
    df['DAYS_EMPLOYED'].replace(365243, np.nan, inplace= True)
    # Some simple new features (percentages)
    df['DAYS_EMPLOYED_PERC'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH']
    df['DAYS_EMPLOYED_DIFF'] = df['DAYS_EMPLOYED'] - df['DAYS_BIRTH']
    df['INCOME_CREDIT_PERC'] = df['AMT_INCOME_TOTAL'] / df['AMT_CREDIT']
    df['INCOME_PER_PERSON'] = df['AMT_INCOME_TOTAL'] / df['CNT_FAM_MEMBERS']
    df['ANNUITY_INCOME_PERC'] = df['AMT_ANNUITY'] / df['AMT_INCOME_TOTAL']
    df['PAYMENT_RATE'] = df['AMT_ANNUITY'] / df['AMT_CREDIT']
    return df

# %%
# Preprocess bureau.csv and bureau_balance.csv
def bureau_and_balance(num_rows = None, nan_as_category = True):
    bureau = pd.read_csv(os.path.join(DATA_DIR, 'bureau.csv'), nrows = num_rows)
    bb = pd.read_csv(os.path.join(DATA_DIR, 'bureau_balance.csv'), nrows = num_rows)
    bb, bb_cat = one_hot_encoder(bb, nan_as_category)
    bureau, bureau_cat = one_hot_encoder(bureau, nan_as_category)
    
    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    for col in bb_cat:
        bb_aggregations[col] = ['mean']
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)

    # Bureau and bureau_balance numeric features
    num_aggregations = {
        'DAYS_CREDIT': ['min', 'max', 'mean', 'var'],
        'DAYS_CREDIT_ENDDATE': ['min', 'max', 'mean'],
        'DAYS_CREDIT_UPDATE': ['mean'],
        'CREDIT_DAY_OVERDUE': ['max', 'mean'],
        'AMT_CREDIT_MAX_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_DEBT': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
        'AMT_ANNUITY': ['max', 'mean'],
        'CNT_CREDIT_PROLONG': ['sum'],
        'MONTHS_BALANCE_MIN': ['min'],
        'MONTHS_BALANCE_MAX': ['max'],
        'MONTHS_BALANCE_SIZE': ['mean', 'sum']
    }
    # Bureau and bureau_balance categorical features
    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']
    
    bureau_agg = bureau.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    # Bureau: Active credits - using only numerical aggregations
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(active_agg, how='left', on='SK_ID_CURR')

    # Bureau: Closed credits - using only numerical aggregations
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')

    return bureau_agg

# %%
# Preprocess previous_applications.csv
def previous_applications(num_rows = None, nan_as_category = True):
    prev = pd.read_csv(os.path.join(DATA_DIR, 'previous_application.csv'), nrows = num_rows)
    prev, cat_cols = one_hot_encoder(prev, nan_as_category= True)
    # Days 365.243 values -> nan
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # Add feature: value ask / value received percentage
    prev['APP_CREDIT_PERC'] = prev['AMT_APPLICATION'] / prev['AMT_CREDIT']
    # Previous applications numeric features
    num_aggregations = {
        'AMT_ANNUITY': ['min', 'max', 'mean'],
        'AMT_APPLICATION': ['min', 'max', 'mean'],
        'AMT_CREDIT': ['min', 'max', 'mean'],
        'APP_CREDIT_PERC': ['min', 'max', 'mean', 'var'],
        'AMT_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'AMT_GOODS_PRICE': ['min', 'max', 'mean'],
        'HOUR_APPR_PROCESS_START': ['min', 'max', 'mean'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
    }
    # Previous applications categorical features
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']
    
    prev_agg = prev.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])
    # Previous Applications: Approved Applications - only numerical features
    approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    prev_agg = prev_agg.join(approved_agg, how='left', on='SK_ID_CURR')
    # Previous Applications: Refused Applications - only numerical features
    refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    return prev_agg

# %%
# Preprocess POS_CASH_balance.csv
def pos_cash(num_rows = None, nan_as_category = True):
    pos = pd.read_csv(os.path.join(DATA_DIR, 'POS_CASH_balance.csv'), nrows = num_rows)
    pos, cat_cols = one_hot_encoder(pos, nan_as_category= True)
    # Features
    aggregations = {
        'MONTHS_BALANCE': ['max', 'mean', 'size'],
        'SK_DPD': ['max', 'mean'],
        'SK_DPD_DEF': ['max', 'mean']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    
    pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
    pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
    # Count pos cash accounts
    pos_agg['POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
    return pos_agg

# %%
# Preprocess installments_payments.csv
def installments_payments(num_rows = None, nan_as_category = True):
    ins = pd.read_csv(os.path.join(DATA_DIR, 'installments_payments.csv'), nrows = num_rows)
    ins, cat_cols = one_hot_encoder(ins, nan_as_category= True)
    # Percentage and difference paid in each installment (amount paid and installment value)
    ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
    ins['PAYMENT_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']
    # Days past due and days before due (no negative values)
    ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
    ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
    ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
    ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)
    # Features: Perform aggregations
    aggregations = {
        'NUM_INSTALMENT_VERSION': ['nunique'],
        'DPD': ['max', 'mean', 'sum'],
        'DBD': ['max', 'mean', 'sum'],
        'PAYMENT_PERC': ['max', 'mean', 'sum', 'var'],
        'PAYMENT_DIFF': ['max', 'mean', 'sum', 'var'],
        'AMT_INSTALMENT': ['max', 'mean', 'sum'],
        'AMT_PAYMENT': ['min', 'max', 'mean', 'sum'],
        'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
    ins_agg.columns = pd.Index(['INSTAL_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    # Count installments accounts
    ins_agg['INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
    return ins_agg

# %%
# Preprocess credit_card_balance.csv
def credit_card_balance(num_rows = None, nan_as_category = True):
    cc = pd.read_csv(os.path.join(DATA_DIR, 'credit_card_balance.csv'), nrows = num_rows)
    cc, cat_cols = one_hot_encoder(cc, nan_as_category= True)
    # General aggregations
    cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    cc_agg = cc.groupby('SK_ID_CURR').agg(['min', 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    # Count credit card lines
    cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()

    return cc_agg

# %%
# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.show()

# %%
def feature_generation():
    num_rows = 10000
    df = application_train_test(num_rows)
    with timer("Process bureau and bureau_balance"):
        bureau = bureau_and_balance(num_rows)
        print("Bureau df shape:", bureau.shape)
        df = df.join(bureau, how='left', on='SK_ID_CURR')

    with timer("Process previous_applications"):
        prev = previous_applications(num_rows)
        print("Previous applications df shape:", prev.shape)
        df = df.join(prev, how='left', on='SK_ID_CURR')

    with timer("Process POS-CASH balance"):
        pos = pos_cash(num_rows)
        print("Pos-cash balance df shape:", pos.shape)
        df = df.join(pos, how='left', on='SK_ID_CURR')

    with timer("Process installments payments"):
        ins = installments_payments(num_rows)
        print("Installments payments df shape:", ins.shape)
        df = df.join(ins, how='left', on='SK_ID_CURR')

    with timer("Process credit card balance"):
        cc = credit_card_balance(num_rows)
        print("Credit card balance df shape:", cc.shape)
        df = df.join(cc, how='left', on='SK_ID_CURR')
    
    print('save feature data to pickle')
    df.to_pickle('feature.pkl')

# %%
# LightGBM GBDT with KFold or Stratified KFold
# Parameters from Tilii kernel: https://www.kaggle.com/tilii7/olivier-lightgbm-parameters-by-bayesian-opt/code
def objective(params):
    # Divide in training/validation and test data
    global ITERATION
    
    ITERATION += 1
    
    

    # Cross validation model
    num_folds = 5
    stratified = False
    
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=1001)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    #sub_preds = np.zeros(test_df.shape[0])
    # feature_importance_df = pd.DataFrame()
    
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['TARGET'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['TARGET'].iloc[valid_idx]

        # Retrieve the subsample if present otherwise set to 1.0
#             subsample = params['boosting_type'].get('subsample', 1.0)

        # Extract the boosting type
#             params['boosting_type'] = params['boosting_type']['boosting_type']
#             params['subsample'] = subsample

        # Make sure parameters that need to be integers are integers
        for parameter_name in ['num_leaves', 'subsample_for_bin', 'min_child_samples']:
            params[parameter_name] = int(params[parameter_name])

        # LightGBM parameters found by Bayesian optimization
        clf = LGBMClassifier(**params)

        clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric= 'auc', verbose= 100, early_stopping_rounds= 200)

        oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration=clf.best_iteration_)[:, 1]
        #sub_preds += clf.predict_proba(test_df[feats], num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

        #print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))

    
    full_auc_score =  roc_auc_score(train_df['TARGET'], oof_preds)
    loss =  1 - full_auc_score
    
    # Write to the csv file ('a' means append)
    of_connection = open('param_tuning_lightgbm.csv', 'a')
    writer = csv.writer(of_connection)
    writer.writerow([loss, params, ITERATION])
    
    
    return {'loss': loss, 'params': params, 'iteration': ITERATION, 'status': STATUS_OK}

# %%
submission_file_name = "submission_kernel02.csv"
with timer("feature generation"):
    feature_generation()
# Out:
# Train samples: 10000, test samples: 10000
# Bureau df shape: (2011, 108)
# Process bureau and bureau_balance - done in 0s
# Previous applications df shape: (9734, 242)
# Process previous_applications - done in 1s
# Pos-cash balance df shape: (9494, 15)
# Process POS-CASH balance - done in 0s
# Installments payments df shape: (8893, 26)
# Process installments payments - done in 0s
# Credit card balance df shape: (9520, 131)
# Process credit card balance - done in 0s
# save feature data to pickle
# feature generation - done in 2s

# %%
# Define the search space
space = {
        'class_weight': hp.choice('class_weight', [None, 'balanced']),
#         'boosting_type': hp.choice('boosting_type', [{'boosting_type': 'gbdt', 'subsample': hp.uniform('gdbt_subsample', 0.5, 1)}, 
#                                                      {'boosting_type': 'dart', 'subsample': hp.uniform('dart_subsample', 0.5, 1)},
#                                                      {'boosting_type': 'goss', 'subsample': 1.0}]),
        'num_leaves': hp.quniform('num_leaves', 30, 150, 1),
        'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(0.2)),
        'subsample_for_bin': hp.quniform('subsample_for_bin', 20000, 300000, 20000),
        'min_child_samples': hp.quniform('min_child_samples', 20, 500, 5),
        'reg_alpha': hp.uniform('reg_alpha', 0.0, 1.0),
        'reg_lambda': hp.uniform('reg_lambda', 0.0, 1.0),
        'colsample_bytree': hp.uniform('colsample_by_tree', 0.6, 1.0)
            }

# %%
global ITERATION
ITERATION = 0

# %%
df = pd.read_pickle('feature.pkl')

# %%
train_df = df[df['TARGET'].notnull()]
test_df = df[df['TARGET'].isnull()]
print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
# Out:
# Starting LightGBM. Train shape: (10000, 769), test shape: (10000, 769)

# %%
bayes_trials = Trials()

# %%
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100, trials=bayes_trials, 
                rstate=np.random.RandomState(50))
# Out:
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.907782	valid_1's auc: 0.772653
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.907782	valid_1's auc: 0.772653
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903359	valid_1's auc: 0.751253
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.903359	valid_1's auc: 0.751253
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.900153	valid_1's auc: 0.777178
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.900153	valid_1's auc: 0.777178
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.901167	valid_1's auc: 0.73364
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.901167	valid_1's auc: 0.73364
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.899183	valid_1's auc: 0.731487
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.899183	valid_1's auc: 0.731487
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999693	valid_1's auc: 0.77322
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999693	valid_1's auc: 0.77322
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999542	valid_1's auc: 0.740027
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999542	valid_1's auc: 0.740027
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999471	valid_1's auc: 0.771911
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999471	valid_1's auc: 0.771911
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999162	valid_1's auc: 0.736124
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999162	valid_1's auc: 0.736124
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999017	valid_1's auc: 0.723198
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999017	valid_1's auc: 0.723198
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.992301	valid_1's auc: 0.765071
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.992301	valid_1's auc: 0.765071
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.990815	valid_1's auc: 0.752503
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.990815	valid_1's auc: 0.752503
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.991567	valid_1's auc: 0.763491
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.991567	valid_1's auc: 0.763491
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.989912	valid_1's auc: 0.739224
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.989912	valid_1's auc: 0.739224
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.98902	valid_1's auc: 0.734986
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.98902	valid_1's auc: 0.734986
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.927222	valid_1's auc: 0.763806
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.927222	valid_1's auc: 0.763806
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.928694	valid_1's auc: 0.754274
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.928694	valid_1's auc: 0.754274
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.925002	valid_1's auc: 0.778811
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.925002	valid_1's auc: 0.778811
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.928148	valid_1's auc: 0.740052
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.928148	valid_1's auc: 0.740052
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.92487	valid_1's auc: 0.730323
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.92487	valid_1's auc: 0.730323
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.87102	valid_1's auc: 0.775964
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.87102	valid_1's auc: 0.775964
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.87108	valid_1's auc: 0.760963
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.87108	valid_1's auc: 0.760963
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.864972	valid_1's auc: 0.781634
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.864972	valid_1's auc: 0.781634
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.869065	valid_1's auc: 0.738212
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.869065	valid_1's auc: 0.738212
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.863907	valid_1's auc: 0.735231
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.863907	valid_1's auc: 0.735231
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.989203	valid_1's auc: 0.740685
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.989203	valid_1's auc: 0.740685
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.989432	valid_1's auc: 0.75155
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.989432	valid_1's auc: 0.75155
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.989261	valid_1's auc: 0.758513
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.989261	valid_1's auc: 0.758513
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.987599	valid_1's auc: 0.747062
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.987599	valid_1's auc: 0.747062
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.986717	valid_1's auc: 0.741469
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.986717	valid_1's auc: 0.741469
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.908412	valid_1's auc: 0.775577
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.908412	valid_1's auc: 0.775577
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.902781	valid_1's auc: 0.754763
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.902781	valid_1's auc: 0.754763
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.901262	valid_1's auc: 0.781353
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.901262	valid_1's auc: 0.781353
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.901759	valid_1's auc: 0.736619
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.901759	valid_1's auc: 0.736619
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.901851	valid_1's auc: 0.738091
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.901851	valid_1's auc: 0.738091
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.996454	valid_1's auc: 0.754565
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.996454	valid_1's auc: 0.754565
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.996447	valid_1's auc: 0.756758
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.996447	valid_1's auc: 0.756758
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.996713	valid_1's auc: 0.765348
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.996713	valid_1's auc: 0.765348
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.995537	valid_1's auc: 0.734524
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.995537	valid_1's auc: 0.734524
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.994932	valid_1's auc: 0.722622
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.994932	valid_1's auc: 0.722622
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.860083	valid_1's auc: 0.775961
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.860083	valid_1's auc: 0.775961
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.862862	valid_1's auc: 0.755511
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.862862	valid_1's auc: 0.755511
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.858616	valid_1's auc: 0.775165
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.858616	valid_1's auc: 0.775165
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.86382	valid_1's auc: 0.741612
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.86382	valid_1's auc: 0.741612
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.858744	valid_1's auc: 0.731565
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.858744	valid_1's auc: 0.731565
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.827957	valid_1's auc: 0.779126
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.827957	valid_1's auc: 0.779126
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.832062	valid_1's auc: 0.749197
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.832062	valid_1's auc: 0.749197
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.822815	valid_1's auc: 0.776694
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.822815	valid_1's auc: 0.776694
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.832554	valid_1's auc: 0.72905
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.832554	valid_1's auc: 0.72905
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.825326	valid_1's auc: 0.724233
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.825326	valid_1's auc: 0.724233
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.901818	valid_1's auc: 0.776742
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.901818	valid_1's auc: 0.776742
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903745	valid_1's auc: 0.756854
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.903745	valid_1's auc: 0.756854
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.897992	valid_1's auc: 0.773378
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.897992	valid_1's auc: 0.773378
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.899668	valid_1's auc: 0.742076
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.899668	valid_1's auc: 0.742076
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.898482	valid_1's auc: 0.732993
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.898482	valid_1's auc: 0.732993
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.980741	valid_1's auc: 0.746985
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.980741	valid_1's auc: 0.746985
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.982972	valid_1's auc: 0.754872
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.982972	valid_1's auc: 0.754872
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.981636	valid_1's auc: 0.747935
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.981636	valid_1's auc: 0.747935
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.979584	valid_1's auc: 0.72727
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.979584	valid_1's auc: 0.72727
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.977946	valid_1's auc: 0.723887
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.977946	valid_1's auc: 0.723887
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999714	valid_1's auc: 0.755961
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999714	valid_1's auc: 0.755961
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.99965	valid_1's auc: 0.758837
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.99965	valid_1's auc: 0.758837
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999745	valid_1's auc: 0.770336
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999745	valid_1's auc: 0.770336
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999588	valid_1's auc: 0.745038
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999588	valid_1's auc: 0.745038
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999525	valid_1's auc: 0.725221
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999525	valid_1's auc: 0.725221
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.889206	valid_1's auc: 0.775553
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.889206	valid_1's auc: 0.775553
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.890755	valid_1's auc: 0.755377
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.890755	valid_1's auc: 0.755377
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.885075	valid_1's auc: 0.777619
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.885075	valid_1's auc: 0.777619
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.890012	valid_1's auc: 0.738021
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.890012	valid_1's auc: 0.738021
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.886311	valid_1's auc: 0.738558
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.886311	valid_1's auc: 0.738558
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.940217	valid_1's auc: 0.767452
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.940217	valid_1's auc: 0.767452
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.940984	valid_1's auc: 0.753337
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.940984	valid_1's auc: 0.753337
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.934087	valid_1's auc: 0.783671
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.934087	valid_1's auc: 0.783671
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.936668	valid_1's auc: 0.738396
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.936668	valid_1's auc: 0.738396
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.934531	valid_1's auc: 0.746124
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.934531	valid_1's auc: 0.746124
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.965479	valid_1's auc: 0.743156
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.965479	valid_1's auc: 0.743156
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.965979	valid_1's auc: 0.749523
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.965979	valid_1's auc: 0.749523
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.963976	valid_1's auc: 0.756608
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.963976	valid_1's auc: 0.756608
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.965268	valid_1's auc: 0.726159
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.965268	valid_1's auc: 0.726159
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.961497	valid_1's auc: 0.725373
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.961497	valid_1's auc: 0.725373
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.91804	valid_1's auc: 0.772736
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.91804	valid_1's auc: 0.772736
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.914372	valid_1's auc: 0.747579
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.914372	valid_1's auc: 0.747579
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.915106	valid_1's auc: 0.778505
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.915106	valid_1's auc: 0.778505
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.914265	valid_1's auc: 0.731318
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.914265	valid_1's auc: 0.731318
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.911763	valid_1's auc: 0.722883
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.911763	valid_1's auc: 0.722883
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.962753	valid_1's auc: 0.768074
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.962753	valid_1's auc: 0.768074
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.962519	valid_1's auc: 0.755275
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.962519	valid_1's auc: 0.755275
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.962938	valid_1's auc: 0.771584
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.962938	valid_1's auc: 0.771584
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.958998	valid_1's auc: 0.740381
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.958998	valid_1's auc: 0.740381
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.955358	valid_1's auc: 0.73952
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.955358	valid_1's auc: 0.73952
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.963667	valid_1's auc: 0.761428
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.963667	valid_1's auc: 0.761428
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.966277	valid_1's auc: 0.743198
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.966277	valid_1's auc: 0.743198
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.963561	valid_1's auc: 0.771859
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.963561	valid_1's auc: 0.771859
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.961424	valid_1's auc: 0.746029
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.961424	valid_1's auc: 0.746029
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.957283	valid_1's auc: 0.737566
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.957283	valid_1's auc: 0.737566
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.99975	valid_1's auc: 0.749132
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.99975	valid_1's auc: 0.749132
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999775	valid_1's auc: 0.742469
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999775	valid_1's auc: 0.742469
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999585	valid_1's auc: 0.773194
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999585	valid_1's auc: 0.773194
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999513	valid_1's auc: 0.722019
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999513	valid_1's auc: 0.722019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999481	valid_1's auc: 0.722774
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999481	valid_1's auc: 0.722774
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.881922	valid_1's auc: 0.773732
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.881922	valid_1's auc: 0.773732
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.882575	valid_1's auc: 0.758354
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.882575	valid_1's auc: 0.758354
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.878386	valid_1's auc: 0.782232
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.878386	valid_1's auc: 0.782232
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.882258	valid_1's auc: 0.732606
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.882258	valid_1's auc: 0.732606
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.87954	valid_1's auc: 0.742687
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.87954	valid_1's auc: 0.742687
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.886629	valid_1's auc: 0.776095
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.886629	valid_1's auc: 0.776095
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.884159	valid_1's auc: 0.7554
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.884159	valid_1's auc: 0.7554
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.879433	valid_1's auc: 0.782225
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.879433	valid_1's auc: 0.782225
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.882879	valid_1's auc: 0.734033
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.882879	valid_1's auc: 0.734033
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.881935	valid_1's auc: 0.741956
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.881935	valid_1's auc: 0.741956
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.845762	valid_1's auc: 0.774509
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.845762	valid_1's auc: 0.774509
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.849006	valid_1's auc: 0.740263
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.849006	valid_1's auc: 0.740263
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.842205	valid_1's auc: 0.77869
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.842205	valid_1's auc: 0.77869
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.844997	valid_1's auc: 0.720904
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.844997	valid_1's auc: 0.720904
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.844965	valid_1's auc: 0.724797
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.844965	valid_1's auc: 0.724797
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.854447	valid_1's auc: 0.776773
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.854447	valid_1's auc: 0.776773
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.856963	valid_1's auc: 0.748161
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.856963	valid_1's auc: 0.748161
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.85253	valid_1's auc: 0.775763
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.85253	valid_1's auc: 0.775763
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.852627	valid_1's auc: 0.725448
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.852627	valid_1's auc: 0.725448
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.852328	valid_1's auc: 0.728397
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.852328	valid_1's auc: 0.728397
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.86639	valid_1's auc: 0.774831
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.86639	valid_1's auc: 0.774831
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.868197	valid_1's auc: 0.75383
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.868197	valid_1's auc: 0.75383
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.861497	valid_1's auc: 0.780862
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.861497	valid_1's auc: 0.780862
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.866405	valid_1's auc: 0.730497
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.866405	valid_1's auc: 0.730497
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.865225	valid_1's auc: 0.739403
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.865225	valid_1's auc: 0.739403
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.905578	valid_1's auc: 0.774658
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.905578	valid_1's auc: 0.774658
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.905939	valid_1's auc: 0.75179
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.905939	valid_1's auc: 0.75179
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.898272	valid_1's auc: 0.783901
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.898272	valid_1's auc: 0.783901
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.902041	valid_1's auc: 0.739677
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.902041	valid_1's auc: 0.739677
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.899761	valid_1's auc: 0.740905
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.899761	valid_1's auc: 0.740905
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.871797	valid_1's auc: 0.774177
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.871797	valid_1's auc: 0.774177
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.87229	valid_1's auc: 0.742837
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.87229	valid_1's auc: 0.742837
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.8656	valid_1's auc: 0.775151
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.8656	valid_1's auc: 0.775151
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.868595	valid_1's auc: 0.729312
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.868595	valid_1's auc: 0.729312
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.870326	valid_1's auc: 0.731783
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.870326	valid_1's auc: 0.731783
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.907077	valid_1's auc: 0.774461
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.907077	valid_1's auc: 0.774461
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.906413	valid_1's auc: 0.755511
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.906413	valid_1's auc: 0.755511
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.900991	valid_1's auc: 0.780563
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.900991	valid_1's auc: 0.780563
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904201	valid_1's auc: 0.737631
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.904201	valid_1's auc: 0.737631
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.901916	valid_1's auc: 0.746027
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.901916	valid_1's auc: 0.746027
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.869498	valid_1's auc: 0.775501
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.869498	valid_1's auc: 0.775501
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.870279	valid_1's auc: 0.747099
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.870279	valid_1's auc: 0.747099
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.86152	valid_1's auc: 0.780268
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.86152	valid_1's auc: 0.780268
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.864095	valid_1's auc: 0.729365
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.864095	valid_1's auc: 0.729365
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.866778	valid_1's auc: 0.733106
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.866778	valid_1's auc: 0.733106
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.917329	valid_1's auc: 0.774658
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.917329	valid_1's auc: 0.774658
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.9166	valid_1's auc: 0.749993
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.9166	valid_1's auc: 0.749993
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.91125	valid_1's auc: 0.781679
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.91125	valid_1's auc: 0.781679
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.914315	valid_1's auc: 0.734298
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.914315	valid_1's auc: 0.734298
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.909861	valid_1's auc: 0.740909
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.909861	valid_1's auc: 0.740909
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.881011	valid_1's auc: 0.77079
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.881011	valid_1's auc: 0.77079
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.88343	valid_1's auc: 0.751521
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.88343	valid_1's auc: 0.751521
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.876533	valid_1's auc: 0.781415
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.876533	valid_1's auc: 0.781415
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.879832	valid_1's auc: 0.735756
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.879832	valid_1's auc: 0.735756
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.878669	valid_1's auc: 0.742785
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.878669	valid_1's auc: 0.742785
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.972778	valid_1's auc: 0.763253
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.972778	valid_1's auc: 0.763253
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.971415	valid_1's auc: 0.763706
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.971415	valid_1's auc: 0.763706
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.969774	valid_1's auc: 0.7842
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.969774	valid_1's auc: 0.7842
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.969155	valid_1's auc: 0.73766
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.969155	valid_1's auc: 0.73766
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.967517	valid_1's auc: 0.750467
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.967517	valid_1's auc: 0.750467
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999929	valid_1's auc: 0.738307
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999929	valid_1's auc: 0.738307
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999937	valid_1's auc: 0.746466
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999937	valid_1's auc: 0.746466
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999826	valid_1's auc: 0.753028
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999826	valid_1's auc: 0.753028
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999867	valid_1's auc: 0.721927
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999867	valid_1's auc: 0.721927
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999812	valid_1's auc: 0.731374
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999812	valid_1's auc: 0.731374
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.991149	valid_1's auc: 0.758031
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.991149	valid_1's auc: 0.758031
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.989927	valid_1's auc: 0.744663
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.989927	valid_1's auc: 0.744663
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.989001	valid_1's auc: 0.764016
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.989001	valid_1's auc: 0.764016
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.989162	valid_1's auc: 0.729818
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.989162	valid_1's auc: 0.729818
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.98753	valid_1's auc: 0.73627
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.98753	valid_1's auc: 0.73627
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.985058	valid_1's auc: 0.752553
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.985058	valid_1's auc: 0.752553
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.984454	valid_1's auc: 0.74779
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.984454	valid_1's auc: 0.74779
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.983986	valid_1's auc: 0.781398
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.983986	valid_1's auc: 0.781398
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.982982	valid_1's auc: 0.737819
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.982982	valid_1's auc: 0.737819
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.983582	valid_1's auc: 0.738621
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.983582	valid_1's auc: 0.738621
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.99933	valid_1's auc: 0.744798
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.99933	valid_1's auc: 0.744798
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999063	valid_1's auc: 0.746936
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999063	valid_1's auc: 0.746936
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999218	valid_1's auc: 0.774925
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999218	valid_1's auc: 0.774925
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.99892	valid_1's auc: 0.719676
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.99892	valid_1's auc: 0.719676
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.998818	valid_1's auc: 0.733515
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.998818	valid_1's auc: 0.733515
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.911808	valid_1's auc: 0.781286
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.911808	valid_1's auc: 0.781286
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.912316	valid_1's auc: 0.753651
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.912316	valid_1's auc: 0.753651
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.905823	valid_1's auc: 0.783734
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.905823	valid_1's auc: 0.783734
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.909069	valid_1's auc: 0.743509
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.909069	valid_1's auc: 0.743509
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.907254	valid_1's auc: 0.745595
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.907254	valid_1's auc: 0.745595
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.974039	valid_1's auc: 0.775422
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.974039	valid_1's auc: 0.775422
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.97323	valid_1's auc: 0.750866
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.97323	valid_1's auc: 0.750866
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.973851	valid_1's auc: 0.778443
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.973851	valid_1's auc: 0.778443
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.972309	valid_1's auc: 0.739468
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.972309	valid_1's auc: 0.739468
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.970381	valid_1's auc: 0.746711
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.970381	valid_1's auc: 0.746711
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.966484	valid_1's auc: 0.763059
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.966484	valid_1's auc: 0.763059
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.965434	valid_1's auc: 0.757561
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.965434	valid_1's auc: 0.757561
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.964404	valid_1's auc: 0.778902
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.964404	valid_1's auc: 0.778902
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.96453	valid_1's auc: 0.737193
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.96453	valid_1's auc: 0.737193
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.962294	valid_1's auc: 0.74705
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.962294	valid_1's auc: 0.74705
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.974605	valid_1's auc: 0.762963
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.974605	valid_1's auc: 0.762963
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.97402	valid_1's auc: 0.753887
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.97402	valid_1's auc: 0.753887
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.97084	valid_1's auc: 0.783348
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.97084	valid_1's auc: 0.783348
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.971739	valid_1's auc: 0.741128
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.971739	valid_1's auc: 0.741128
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.969689	valid_1's auc: 0.740664
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.969689	valid_1's auc: 0.740664
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999867	valid_1's auc: 0.740063
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999867	valid_1's auc: 0.740063
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.9999	valid_1's auc: 0.755348
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.9999	valid_1's auc: 0.755348
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.99999	valid_1's auc: 0.749423
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.99999	valid_1's auc: 0.749423
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999907	valid_1's auc: 0.71853
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999907	valid_1's auc: 0.71853
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.999968	valid_1's auc: 0.726245
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.999968	valid_1's auc: 0.726245
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.971378	valid_1's auc: 0.773061
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.971378	valid_1's auc: 0.773061
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.970442	valid_1's auc: 0.751473
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.970442	valid_1's auc: 0.751473
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.971002	valid_1's auc: 0.776948
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.971002	valid_1's auc: 0.776948
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.968819	valid_1's auc: 0.737058
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.968819	valid_1's auc: 0.737058
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.967215	valid_1's auc: 0.739983
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.967215	valid_1's auc: 0.739983
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.895446	valid_1's auc: 0.769494
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.895446	valid_1's auc: 0.769494
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.897824	valid_1's auc: 0.754328
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.897824	valid_1's auc: 0.754328
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.891831	valid_1's auc: 0.773691
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.891831	valid_1's auc: 0.773691
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.896255	valid_1's auc: 0.741213
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.896255	valid_1's auc: 0.741213
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.893061	valid_1's auc: 0.736764
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.893061	valid_1's auc: 0.736764
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 1	valid_1's auc: 0.738432
# Did not meet early stopping. Best iteration is:
# [53]	training's auc: 1	valid_1's auc: 0.747421
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 1	valid_1's auc: 0.747879
# Did not meet early stopping. Best iteration is:
# [65]	training's auc: 1	valid_1's auc: 0.750728
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 1	valid_1's auc: 0.754648
# Did not meet early stopping. Best iteration is:
# ...
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.882698	valid_1's auc: 0.773308
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.884181	valid_1's auc: 0.742593
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.884181	valid_1's auc: 0.742593
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.885021	valid_1's auc: 0.734589
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.885021	valid_1's auc: 0.734589
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.852398	valid_1's auc: 0.779607
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.852398	valid_1's auc: 0.779607
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.855088	valid_1's auc: 0.753152
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.855088	valid_1's auc: 0.753152
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.852351	valid_1's auc: 0.777859
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.852351	valid_1's auc: 0.777859
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.856299	valid_1's auc: 0.739263
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.856299	valid_1's auc: 0.739263
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.851577	valid_1's auc: 0.726809
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.851577	valid_1's auc: 0.726809
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.985435	valid_1's auc: 0.753552
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.985435	valid_1's auc: 0.753552
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.985128	valid_1's auc: 0.748186
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.985128	valid_1's auc: 0.748186
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.985207	valid_1's auc: 0.767767
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.985207	valid_1's auc: 0.767767
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.984201	valid_1's auc: 0.735367
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.984201	valid_1's auc: 0.735367
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.9829	valid_1's auc: 0.733682
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.9829	valid_1's auc: 0.733682
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.972523	valid_1's auc: 0.757219
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.972523	valid_1's auc: 0.757219
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.971579	valid_1's auc: 0.760947
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.971579	valid_1's auc: 0.760947
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.970129	valid_1's auc: 0.775575
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.970129	valid_1's auc: 0.775575
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.971075	valid_1's auc: 0.741138
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.971075	valid_1's auc: 0.741138
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.969512	valid_1's auc: 0.745373
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.969512	valid_1's auc: 0.745373
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.898566	valid_1's auc: 0.778494
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.898566	valid_1's auc: 0.778494
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.897735	valid_1's auc: 0.747774
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.897735	valid_1's auc: 0.747774
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.890695	valid_1's auc: 0.77797
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.890695	valid_1's auc: 0.77797
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.897283	valid_1's auc: 0.735593
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.897283	valid_1's auc: 0.735593
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.891754	valid_1's auc: 0.734783
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.891754	valid_1's auc: 0.734783
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.8895	valid_1's auc: 0.769453
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.8895	valid_1's auc: 0.769453
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.890569	valid_1's auc: 0.755387
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.890569	valid_1's auc: 0.755387
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.886059	valid_1's auc: 0.779114
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.886059	valid_1's auc: 0.779114
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.890843	valid_1's auc: 0.738272
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.890843	valid_1's auc: 0.738272
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.888944	valid_1's auc: 0.737379
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.888944	valid_1's auc: 0.737379
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.850158	valid_1's auc: 0.773597
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.850158	valid_1's auc: 0.773597
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.850128	valid_1's auc: 0.755623
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.850128	valid_1's auc: 0.755623
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.845097	valid_1's auc: 0.778599
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.845097	valid_1's auc: 0.778599
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.849025	valid_1's auc: 0.72819
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.849025	valid_1's auc: 0.72819
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.847289	valid_1's auc: 0.730432
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.847289	valid_1's auc: 0.730432
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.965446	valid_1's auc: 0.767725
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.965446	valid_1's auc: 0.767725
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.963933	valid_1's auc: 0.761129
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.963933	valid_1's auc: 0.761129
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.96121	valid_1's auc: 0.771939
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.96121	valid_1's auc: 0.771939
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.962785	valid_1's auc: 0.740469
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.962785	valid_1's auc: 0.740469
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.961953	valid_1's auc: 0.7352
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.961953	valid_1's auc: 0.7352
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.875327	valid_1's auc: 0.777765
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.875327	valid_1's auc: 0.777765
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.874972	valid_1's auc: 0.755643
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.874972	valid_1's auc: 0.755643
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.872734	valid_1's auc: 0.770514
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.872734	valid_1's auc: 0.770514
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.876125	valid_1's auc: 0.738739
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.876125	valid_1's auc: 0.738739
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.873152	valid_1's auc: 0.734184
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.873152	valid_1's auc: 0.734184
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.996333	valid_1's auc: 0.758297
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.996333	valid_1's auc: 0.758297
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.994975	valid_1's auc: 0.749443
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.994975	valid_1's auc: 0.749443
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.995795	valid_1's auc: 0.761204
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.995795	valid_1's auc: 0.761204
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.994893	valid_1's auc: 0.731577
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.994893	valid_1's auc: 0.731577
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.994589	valid_1's auc: 0.729405
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.994589	valid_1's auc: 0.729405
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.937807	valid_1's auc: 0.773224
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.937807	valid_1's auc: 0.773224
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.939446	valid_1's auc: 0.755374
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.939446	valid_1's auc: 0.755374
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.935907	valid_1's auc: 0.780066
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.935907	valid_1's auc: 0.780066
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.936514	valid_1's auc: 0.741018
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.936514	valid_1's auc: 0.741018
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.933347	valid_1's auc: 0.749319
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.933347	valid_1's auc: 0.749319
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.933066	valid_1's auc: 0.763699
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.933066	valid_1's auc: 0.763699
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.934004	valid_1's auc: 0.747982
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.934004	valid_1's auc: 0.747982
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.931399	valid_1's auc: 0.77821
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.931399	valid_1's auc: 0.77821
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.929887	valid_1's auc: 0.734981
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.929887	valid_1's auc: 0.734981
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.929943	valid_1's auc: 0.739788
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.929943	valid_1's auc: 0.739788
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.963403	valid_1's auc: 0.759949
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.963403	valid_1's auc: 0.759949
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.962755	valid_1's auc: 0.760614
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.962755	valid_1's auc: 0.760614
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.960968	valid_1's auc: 0.779465
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.960968	valid_1's auc: 0.779465
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.961636	valid_1's auc: 0.746652
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.961636	valid_1's auc: 0.746652
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.958694	valid_1's auc: 0.754164
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.958694	valid_1's auc: 0.754164
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.932418	valid_1's auc: 0.765299
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.932418	valid_1's auc: 0.765299
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.932264	valid_1's auc: 0.751396
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.932264	valid_1's auc: 0.751396
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.929384	valid_1's auc: 0.780143
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.929384	valid_1's auc: 0.780143
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.932475	valid_1's auc: 0.729875
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.932475	valid_1's auc: 0.729875
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.928683	valid_1's auc: 0.732098
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.928683	valid_1's auc: 0.732098
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.870444	valid_1's auc: 0.769304
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.870444	valid_1's auc: 0.769304
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.872618	valid_1's auc: 0.755109
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.872618	valid_1's auc: 0.755109
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.864522	valid_1's auc: 0.775332
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.864522	valid_1's auc: 0.775332
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.869855	valid_1's auc: 0.738099
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.869855	valid_1's auc: 0.738099
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.869456	valid_1's auc: 0.72844
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.869456	valid_1's auc: 0.72844

# %%
bayes_trials_results = sorted(bayes_trials.results, key = lambda x: x['loss'])

# %%
bayes_trials_results[:2]
